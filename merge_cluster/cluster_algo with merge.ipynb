# %%
import numpy as np
import pandas as pd

# %%
# If your file is named like this:

data = pd.read_csv("../data/vpufs_reduced_features.csv")

data = data.dropna(axis=1)
data = data.loc[:, ~data.columns.duplicated()]
data = data.apply(pd.to_numeric, errors='coerce')
data = data.dropna()

# 3. Extract features and labels
labels = data.iloc[:, -1].values
features_df = data.drop(data.columns[-1], axis=1)


print(data.shape)

print(data.head())
# Out:
# (624, 1000)
#     586        384    87    751    81       262   697   581   364   383  ...  \
# 0  52.5  29.600000  65.4  11.20  22.5  3.580000  15.3  21.8  2.95  25.1  ...
# 1  63.6  42.800000  68.7  12.00  27.3  4.620000  20.2  27.7  3.27  31.9  ...
# 2  47.6   1.505021  75.8  10.20  32.6  3.310000  16.2  20.5  5.22  28.8  ...
# 3  59.2  40.100000  62.1  14.00  27.2  3.300000  18.9  30.9  5.48  26.5  ...
# 4  40.9  37.500000  74.7   4.61  32.9  1.510252  16.9  24.3  1.56  30.0  ...
#
#      884   634    29   172   263    45   741   378        906    840
# 0  3.050  14.3  5.92  6.76  11.3  13.6  1.99  64.1  32.300000  12.70
# 1  1.660  18.3  6.83  8.31  15.7  20.9  2.31  47.6  30.400000   8.12
# 2  0.625  15.6  9.65  7.63  15.8  19.2  1.86  43.5  23.800000   8.85
# 3  3.580  16.1  7.15  6.30  11.3  19.6  2.15  54.8  31.100000  10.80
# 4  1.170  15.9  9.72  5.24  14.4  18.5  2.15  42.1   1.510252   9.81
#
# [5 rows x 1000 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist

# def reduce_features(X, y=None, k=1000):
#     """ Reduce gene expression matrix to top k features """
#     if y is None:
#         # Use variance threshold if labels are not present
#         from sklearn.feature_selection import VarianceThreshold
#         selector = VarianceThreshold(threshold=0.01)
#         X_new = selector.fit_transform(X)
#         if X_new.shape[1] > k:
#             X_new = X_new[:, :k]
#         return X_new
#     else:
#         selector = SelectKBest(score_func=f_classif, k=k)
#         X_new = selector.fit_transform(X, y)
#         return X_new

def normalized_euclidean_similarity(X):
    """ Compute (1 - normalized Euclidean distance) similarity matrix """
    # Normalize data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Euclidean distances
    distances = cdist(X_scaled, X_scaled, metric='euclidean')
    
    # Normalize distances to [0, 1]
    max_dist = distances.max()
    normalized_dist = distances / max_dist
    
    # Convert to similarity
    similarity = 1 - normalized_dist
    return similarity

def build_clusters(similarity_matrix, r=0.9):
    """ Identify neighbors based on similarity threshold and count densities """
    n_samples = similarity_matrix.shape[0]
    clusters = []
    densities = []
    
    for i in range(n_samples):
        neighbors = np.where(similarity_matrix[i] >= r)[0]
        clusters.append(neighbors)
        densities.append(len(neighbors))
    
    return clusters, densities



def run_pipeline(data: pd.DataFrame, labels=None, k=1000, r=0.9):
    # print("Step 1: Reducing features...")
    # reduced_data = reduce_features(data.values, y=labels, k=k)
    # print(f"Reduced shape: {reduced_data.shape}")
    
    print("Step 2: Computing similarity matrix...")
    similarity = normalized_euclidean_similarity(data)
    
    print("Step 3: Identifying neighbors and densities...")
    clusters, densities = build_clusters(similarity, r=r)
    
    return clusters, densities, similarity

# %%
clusters, densities, similarity = run_pipeline(features_df, labels=labels, k=1000, r=0.862)



# Combine index, density, and cluster info into a list of tuples
sample_info = [(i, densities[i], clusters[i]) for i in range(len(clusters))]

# Now sort that list by density (2nd item in tuple) in descending order
sample_info_sorted = sorted(sample_info, key=lambda x: x[1], reverse=True)

# Print sorted result
for i, density, neighbors in sample_info_sorted[:50]:
    print(f"Sample {i}: Density = {density}")
    print(f"Neighbors: {neighbors}")
    print("-----------")
    print()
# Out:
# Step 2: Computing similarity matrix...
# Step 3: Identifying neighbors and densities...
# Sample 465: Density = 7
# Neighbors: [443 454 460 461 464 465 466]
# -----------
#
# Sample 466: Density = 7
# Neighbors: [443 450 451 454 461 465 466]
# -----------
#
# Sample 536: Density = 6
# Neighbors: [490 498 503 525 536 538]
# -----------
#
# Sample 426: Density = 5
# Neighbors: [316 347 409 421 426]
# -----------
#
# Sample 461: Density = 5
# Neighbors: [443 461 462 465 466]
# -----------
#
# Sample 2: Density = 4
# Neighbors: [  2 316 322 409]
# -----------
#
# Sample 322: Density = 4
# Neighbors: [  2 322 338 413]
# -----------
#
# Sample 409: Density = 4
# Neighbors: [  2 409 413 426]
# -----------
#
# Sample 443: Density = 4
# Neighbors: [443 461 465 466]
# -----------
#
# Sample 490: Density = 4
# Neighbors: [490 525 536 538]
# -----------
#
# Sample 498: Density = 4
# Neighbors: [498 505 536 552]
# -----------
#
# Sample 505: Density = 4
# Neighbors: [442 498 505 538]
# -----------
#
# Sample 538: Density = 4
# Neighbors: [490 505 536 538]
# -----------
#
# Sample 286: Density = 3
# Neighbors: [286 287 289]
# -----------
#
# Sample 287: Density = 3
# Neighbors: [286 287 293]
# -----------
#
# Sample 316: Density = 3
# Neighbors: [  2 316 426]
# -----------
#
# Sample 338: Density = 3
# Neighbors: [322 338 376]
# -----------
#
# Sample 413: Density = 3
# Neighbors: [322 409 413]
# -----------
#
# Sample 454: Density = 3
# Neighbors: [454 465 466]
# -----------
#
# Sample 525: Density = 3
# Neighbors: [490 525 536]
# -----------
#
# Sample 527: Density = 3
# Neighbors: [527 552 556]
# -----------
#
# Sample 552: Density = 3
# Neighbors: [498 527 552]
# -----------
#
# Sample 556: Density = 3
# Neighbors: [172 527 556]
# -----------
#
# Sample 603: Density = 3
# Neighbors: [597 600 603]
# -----------
#
# Sample 103: Density = 2
# Neighbors: [103 139]
# -----------
#
# Sample 139: Density = 2
# Neighbors: [103 139]
# -----------
#
# Sample 172: Density = 2
# Neighbors: [172 556]
# -----------
#
# Sample 264: Density = 2
# Neighbors: [264 269]
# -----------
#
# Sample 269: Density = 2
# Neighbors: [264 269]
# -----------
#
# Sample 285: Density = 2
# Neighbors: [285 288]
# -----------
#
# Sample 288: Density = 2
# Neighbors: [285 288]
# -----------
#
# Sample 289: Density = 2
# Neighbors: [286 289]
# -----------
#
# Sample 293: Density = 2
# Neighbors: [287 293]
# -----------
#
# Sample 347: Density = 2
# Neighbors: [347 426]
# -----------
#
# Sample 376: Density = 2
# Neighbors: [338 376]
# -----------
#
# Sample 421: Density = 2
# Neighbors: [421 426]
# -----------
#
# Sample 442: Density = 2
# Neighbors: [442 505]
# -----------
#
# Sample 450: Density = 2
# Neighbors: [450 466]
# -----------
#
# Sample 451: Density = 2
# Neighbors: [451 466]
# -----------
#
# Sample 460: Density = 2
# Neighbors: [460 465]
# -----------
#
# Sample 462: Density = 2
# Neighbors: [461 462]
# -----------
#
# Sample 464: Density = 2
# Neighbors: [464 465]
# -----------
#
# Sample 477: Density = 2
# Neighbors: [477 551]
# -----------
#
# Sample 497: Density = 2
# Neighbors: [497 550]
# -----------
#
# Sample 499: Density = 2
# Neighbors: [499 533]
# -----------
#
# Sample 503: Density = 2
# Neighbors: [503 536]
# -----------
#
# Sample 533: Density = 2
# Neighbors: [499 533]
# -----------
#
# Sample 548: Density = 2
# Neighbors: [548 563]
# -----------
#
# Sample 550: Density = 2
# Neighbors: [497 550]
# -----------
#
# Sample 551: Density = 2
# Neighbors: [477 551]
# -----------

# %%
def merge_clusters(sample_info_sorted, threshold=0.5):
    """
    Merge clusters if they share more than `threshold` of the total number of samples.
    The merging will be based on the ratio of common samples to the total distinct samples.
    """
    merged = []
    visited = set()

    for i, density_i, cluster_i in sample_info_sorted:
        if i in visited:
            continue

        # Start new merged cluster
        merged_cluster = set(cluster_i)
        merged_indices = {i}
        visited.add(i)

        changed = True
        while changed:
            changed = False
            for j, density_j, cluster_j in sample_info_sorted:
                if j in visited:
                    continue

                set_j = set(cluster_j)
                common = merged_cluster.intersection(set_j)  # common samples
                union = merged_cluster.union(set_j)  # total distinct samples
                common_size = len(common)
                union_size = len(union)

                # Calculate the ratio of common samples to total distinct samples
                similarity_ratio = common_size / union_size if union_size > 0 else 0

                # Merge if similarity ratio exceeds threshold
                if similarity_ratio > threshold:
                    merged_cluster.update(set_j)
                    visited.add(j)
                    merged_indices.add(j)
                    changed = True

        merged.append(list(merged_cluster))

    return merged

# %%
# Step 1: Sort by density (already done)
sample_info = [(i, densities[i], clusters[i]) for i in range(len(clusters))]
sample_info_sorted = sorted(sample_info, key=lambda x: x[1], reverse=True)

# Step 2: Merge clusters based on >50% overlap rule
merged_clusters = merge_clusters(sample_info_sorted)

# Step 3: Print merged cluster summary
print(f"Total merged clusters: {len(merged_clusters)}")
for idx, cluster in enumerate(merged_clusters):
    print(f"Merged Cluster {idx+1}: Size = {len(cluster)} Samples = {sorted([int(i) for i in cluster])}")
# Out:
# Total merged clusters: 607
# Merged Cluster 1: Size = 9 Samples = [443, 450, 451, 454, 460, 461, 464, 465, 466]
# Merged Cluster 2: Size = 6 Samples = [490, 498, 503, 525, 536, 538]
# Merged Cluster 3: Size = 5 Samples = [316, 347, 409, 421, 426]
# Merged Cluster 4: Size = 5 Samples = [443, 461, 462, 465, 466]
# Merged Cluster 5: Size = 4 Samples = [2, 316, 322, 409]
# Merged Cluster 6: Size = 4 Samples = [2, 322, 338, 413]
# Merged Cluster 7: Size = 4 Samples = [2, 409, 413, 426]
# Merged Cluster 8: Size = 4 Samples = [498, 505, 536, 552]
# Merged Cluster 9: Size = 4 Samples = [442, 498, 505, 538]
# Merged Cluster 10: Size = 4 Samples = [490, 505, 536, 538]
# Merged Cluster 11: Size = 3 Samples = [286, 287, 289]
# Merged Cluster 12: Size = 3 Samples = [286, 287, 293]
# Merged Cluster 13: Size = 3 Samples = [2, 316, 426]
# Merged Cluster 14: Size = 3 Samples = [322, 338, 376]
# Merged Cluster 15: Size = 3 Samples = [322, 409, 413]
# Merged Cluster 16: Size = 3 Samples = [454, 465, 466]
# Merged Cluster 17: Size = 3 Samples = [490, 525, 536]
# Merged Cluster 18: Size = 3 Samples = [527, 552, 556]
# Merged Cluster 19: Size = 3 Samples = [498, 527, 552]
# Merged Cluster 20: Size = 3 Samples = [172, 527, 556]
# Merged Cluster 21: Size = 3 Samples = [597, 600, 603]
# Merged Cluster 22: Size = 2 Samples = [103, 139]
# Merged Cluster 23: Size = 2 Samples = [264, 269]
# Merged Cluster 24: Size = 2 Samples = [285, 288]
# Merged Cluster 25: Size = 2 Samples = [347, 426]
# Merged Cluster 26: Size = 2 Samples = [421, 426]
# Merged Cluster 27: Size = 2 Samples = [442, 505]
# Merged Cluster 28: Size = 2 Samples = [450, 466]
# Merged Cluster 29: Size = 2 Samples = [451, 466]
# Merged Cluster 30: Size = 2 Samples = [460, 465]
# Merged Cluster 31: Size = 2 Samples = [461, 462]
# Merged Cluster 32: Size = 2 Samples = [464, 465]
# Merged Cluster 33: Size = 2 Samples = [477, 551]
# Merged Cluster 34: Size = 2 Samples = [497, 550]
# Merged Cluster 35: Size = 2 Samples = [499, 533]
# Merged Cluster 36: Size = 2 Samples = [503, 536]
# Merged Cluster 37: Size = 2 Samples = [548, 563]
# Merged Cluster 38: Size = 2 Samples = [568, 576]
# Merged Cluster 39: Size = 1 Samples = [0]
# Merged Cluster 40: Size = 1 Samples = [1]
# Merged Cluster 41: Size = 1 Samples = [3]
# Merged Cluster 42: Size = 1 Samples = [4]
# Merged Cluster 43: Size = 1 Samples = [5]
# Merged Cluster 44: Size = 1 Samples = [6]
# Merged Cluster 45: Size = 1 Samples = [7]
# Merged Cluster 46: Size = 1 Samples = [8]
# Merged Cluster 47: Size = 1 Samples = [9]
# Merged Cluster 48: Size = 1 Samples = [10]
# Merged Cluster 49: Size = 1 Samples = [11]
# Merged Cluster 50: Size = 1 Samples = [12]
# Merged Cluster 51: Size = 1 Samples = [13]
# Merged Cluster 52: Size = 1 Samples = [14]
# Merged Cluster 53: Size = 1 Samples = [15]
# Merged Cluster 54: Size = 1 Samples = [16]
# Merged Cluster 55: Size = 1 Samples = [17]
# Merged Cluster 56: Size = 1 Samples = [18]
# Merged Cluster 57: Size = 1 Samples = [19]
# Merged Cluster 58: Size = 1 Samples = [20]
# Merged Cluster 59: Size = 1 Samples = [21]
# Merged Cluster 60: Size = 1 Samples = [22]
# Merged Cluster 61: Size = 1 Samples = [23]
# Merged Cluster 62: Size = 1 Samples = [24]
# Merged Cluster 63: Size = 1 Samples = [25]
# Merged Cluster 64: Size = 1 Samples = [26]
# Merged Cluster 65: Size = 1 Samples = [27]
# Merged Cluster 66: Size = 1 Samples = [28]
# Merged Cluster 67: Size = 1 Samples = [29]
# Merged Cluster 68: Size = 1 Samples = [30]
# Merged Cluster 69: Size = 1 Samples = [31]
# Merged Cluster 70: Size = 1 Samples = [32]
# Merged Cluster 71: Size = 1 Samples = [33]
# Merged Cluster 72: Size = 1 Samples = [34]
# Merged Cluster 73: Size = 1 Samples = [35]
# Merged Cluster 74: Size = 1 Samples = [36]
# Merged Cluster 75: Size = 1 Samples = [37]
# Merged Cluster 76: Size = 1 Samples = [38]
# Merged Cluster 77: Size = 1 Samples = [39]
# Merged Cluster 78: Size = 1 Samples = [40]
# Merged Cluster 79: Size = 1 Samples = [41]
# Merged Cluster 80: Size = 1 Samples = [42]
# Merged Cluster 81: Size = 1 Samples = [43]
# Merged Cluster 82: Size = 1 Samples = [44]
# Merged Cluster 83: Size = 1 Samples = [45]
# Merged Cluster 84: Size = 1 Samples = [46]
# Merged Cluster 85: Size = 1 Samples = [47]
# Merged Cluster 86: Size = 1 Samples = [48]
# Merged Cluster 87: Size = 1 Samples = [49]
# Merged Cluster 88: Size = 1 Samples = [50]
# Merged Cluster 89: Size = 1 Samples = [51]
# Merged Cluster 90: Size = 1 Samples = [52]
# Merged Cluster 91: Size = 1 Samples = [53]
# Merged Cluster 92: Size = 1 Samples = [54]
# Merged Cluster 93: Size = 1 Samples = [55]
# Merged Cluster 94: Size = 1 Samples = [56]
# Merged Cluster 95: Size = 1 Samples = [57]
# Merged Cluster 96: Size = 1 Samples = [58]
# Merged Cluster 97: Size = 1 Samples = [59]
# Merged Cluster 98: Size = 1 Samples = [60]
# Merged Cluster 99: Size = 1 Samples = [61]
# Merged Cluster 100: Size = 1 Samples = [62]
# Merged Cluster 101: Size = 1 Samples = [63]
# Merged Cluster 102: Size = 1 Samples = [64]
# Merged Cluster 103: Size = 1 Samples = [65]
# Merged Cluster 104: Size = 1 Samples = [66]
# Merged Cluster 105: Size = 1 Samples = [67]
# Merged Cluster 106: Size = 1 Samples = [68]
# Merged Cluster 107: Size = 1 Samples = [69]
# Merged Cluster 108: Size = 1 Samples = [70]
# Merged Cluster 109: Size = 1 Samples = [71]
# Merged Cluster 110: Size = 1 Samples = [72]
# Merged Cluster 111: Size = 1 Samples = [73]
# Merged Cluster 112: Size = 1 Samples = [74]
# Merged Cluster 113: Size = 1 Samples = [75]
# Merged Cluster 114: Size = 1 Samples = [76]
# Merged Cluster 115: Size = 1 Samples = [77]
# Merged Cluster 116: Size = 1 Samples = [78]
# Merged Cluster 117: Size = 1 Samples = [79]
# Merged Cluster 118: Size = 1 Samples = [80]
# Merged Cluster 119: Size = 1 Samples = [81]
# Merged Cluster 120: Size = 1 Samples = [82]
# Merged Cluster 121: Size = 1 Samples = [83]
# Merged Cluster 122: Size = 1 Samples = [84]
# Merged Cluster 123: Size = 1 Samples = [85]
# Merged Cluster 124: Size = 1 Samples = [86]
# Merged Cluster 125: Size = 1 Samples = [87]
# Merged Cluster 126: Size = 1 Samples = [88]
# Merged Cluster 127: Size = 1 Samples = [89]
# Merged Cluster 128: Size = 1 Samples = [90]
# Merged Cluster 129: Size = 1 Samples = [91]
# Merged Cluster 130: Size = 1 Samples = [92]
# Merged Cluster 131: Size = 1 Samples = [93]
# Merged Cluster 132: Size = 1 Samples = [94]
# Merged Cluster 133: Size = 1 Samples = [95]
# Merged Cluster 134: Size = 1 Samples = [96]
# Merged Cluster 135: Size = 1 Samples = [97]
# Merged Cluster 136: Size = 1 Samples = [98]
# Merged Cluster 137: Size = 1 Samples = [99]
# Merged Cluster 138: Size = 1 Samples = [100]
# Merged Cluster 139: Size = 1 Samples = [101]
# Merged Cluster 140: Size = 1 Samples = [102]
# Merged Cluster 141: Size = 1 Samples = [104]
# Merged Cluster 142: Size = 1 Samples = [105]
# Merged Cluster 143: Size = 1 Samples = [106]
# Merged Cluster 144: Size = 1 Samples = [107]
# Merged Cluster 145: Size = 1 Samples = [108]
# Merged Cluster 146: Size = 1 Samples = [109]
# Merged Cluster 147: Size = 1 Samples = [110]
# Merged Cluster 148: Size = 1 Samples = [111]
# Merged Cluster 149: Size = 1 Samples = [112]
# Merged Cluster 150: Size = 1 Samples = [113]
# Merged Cluster 151: Size = 1 Samples = [114]
# Merged Cluster 152: Size = 1 Samples = [115]
# Merged Cluster 153: Size = 1 Samples = [116]
# Merged Cluster 154: Size = 1 Samples = [117]
# Merged Cluster 155: Size = 1 Samples = [118]
# Merged Cluster 156: Size = 1 Samples = [119]
# Merged Cluster 157: Size = 1 Samples = [120]
# Merged Cluster 158: Size = 1 Samples = [121]
# Merged Cluster 159: Size = 1 Samples = [122]
# Merged Cluster 160: Size = 1 Samples = [123]
# Merged Cluster 161: Size = 1 Samples = [124]
# Merged Cluster 162: Size = 1 Samples = [125]
# Merged Cluster 163: Size = 1 Samples = [126]
# Merged Cluster 164: Size = 1 Samples = [127]
# Merged Cluster 165: Size = 1 Samples = [128]
# Merged Cluster 166: Size = 1 Samples = [129]
# Merged Cluster 167: Size = 1 Samples = [130]
# Merged Cluster 168: Size = 1 Samples = [131]
# Merged Cluster 169: Size = 1 Samples = [132]
# Merged Cluster 170: Size = 1 Samples = [133]
# Merged Cluster 171: Size = 1 Samples = [134]
# Merged Cluster 172: Size = 1 Samples = [135]
# Merged Cluster 173: Size = 1 Samples = [136]
# Merged Cluster 174: Size = 1 Samples = [137]
# Merged Cluster 175: Size = 1 Samples = [138]
# Merged Cluster 176: Size = 1 Samples = [140]
# Merged Cluster 177: Size = 1 Samples = [141]
# Merged Cluster 178: Size = 1 Samples = [142]
# Merged Cluster 179: Size = 1 Samples = [143]
# Merged Cluster 180: Size = 1 Samples = [144]
# Merged Cluster 181: Size = 1 Samples = [145]
# Merged Cluster 182: Size = 1 Samples = [146]
# Merged Cluster 183: Size = 1 Samples = [147]
# Merged Cluster 184: Size = 1 Samples = [148]
# Merged Cluster 185: Size = 1 Samples = [149]
# Merged Cluster 186: Size = 1 Samples = [150]
# Merged Cluster 187: Size = 1 Samples = [151]
# Merged Cluster 188: Size = 1 Samples = [152]
# Merged Cluster 189: Size = 1 Samples = [153]
# Merged Cluster 190: Size = 1 Samples = [154]
# Merged Cluster 191: Size = 1 Samples = [155]
# Merged Cluster 192: Size = 1 Samples = [156]
# Merged Cluster 193: Size = 1 Samples = [157]
# Merged Cluster 194: Size = 1 Samples = [158]
# Merged Cluster 195: Size = 1 Samples = [159]
# Merged Cluster 196: Size = 1 Samples = [160]
# Merged Cluster 197: Size = 1 Samples = [161]
# Merged Cluster 198: Size = 1 Samples = [162]
# Merged Cluster 199: Size = 1 Samples = [163]
# Merged Cluster 200: Size = 1 Samples = [164]
# Merged Cluster 201: Size = 1 Samples = [165]
# Merged Cluster 202: Size = 1 Samples = [166]
# Merged Cluster 203: Size = 1 Samples = [167]
# Merged Cluster 204: Size = 1 Samples = [168]
# Merged Cluster 205: Size = 1 Samples = [169]
# Merged Cluster 206: Size = 1 Samples = [170]
# Merged Cluster 207: Size = 1 Samples = [171]
# Merged Cluster 208: Size = 1 Samples = [173]
# Merged Cluster 209: Size = 1 Samples = [174]
# Merged Cluster 210: Size = 1 Samples = [175]
# Merged Cluster 211: Size = 1 Samples = [176]
# Merged Cluster 212: Size = 1 Samples = [177]
# Merged Cluster 213: Size = 1 Samples = [178]
# Merged Cluster 214: Size = 1 Samples = [179]
# Merged Cluster 215: Size = 1 Samples = [180]
# Merged Cluster 216: Size = 1 Samples = [181]
# Merged Cluster 217: Size = 1 Samples = [182]
# Merged Cluster 218: Size = 1 Samples = [183]
# Merged Cluster 219: Size = 1 Samples = [184]
# Merged Cluster 220: Size = 1 Samples = [185]
# Merged Cluster 221: Size = 1 Samples = [186]
# Merged Cluster 222: Size = 1 Samples = [187]
# Merged Cluster 223: Size = 1 Samples = [188]
# Merged Cluster 224: Size = 1 Samples = [189]
# Merged Cluster 225: Size = 1 Samples = [190]
# Merged Cluster 226: Size = 1 Samples = [191]
# Merged Cluster 227: Size = 1 Samples = [192]
# Merged Cluster 228: Size = 1 Samples = [193]
# Merged Cluster 229: Size = 1 Samples = [194]
# Merged Cluster 230: Size = 1 Samples = [195]
# Merged Cluster 231: Size = 1 Samples = [196]
# Merged Cluster 232: Size = 1 Samples = [197]
# Merged Cluster 233: Size = 1 Samples = [198]
# Merged Cluster 234: Size = 1 Samples = [199]
# Merged Cluster 235: Size = 1 Samples = [200]
# Merged Cluster 236: Size = 1 Samples = [201]
# Merged Cluster 237: Size = 1 Samples = [202]
# Merged Cluster 238: Size = 1 Samples = [203]
# Merged Cluster 239: Size = 1 Samples = [204]
# Merged Cluster 240: Size = 1 Samples = [205]
# Merged Cluster 241: Size = 1 Samples = [206]
# Merged Cluster 242: Size = 1 Samples = [207]
# Merged Cluster 243: Size = 1 Samples = [208]
# Merged Cluster 244: Size = 1 Samples = [209]
# Merged Cluster 245: Size = 1 Samples = [210]
# Merged Cluster 246: Size = 1 Samples = [211]
# Merged Cluster 247: Size = 1 Samples = [212]
# Merged Cluster 248: Size = 1 Samples = [213]
# Merged Cluster 249: Size = 1 Samples = [214]
# Merged Cluster 250: Size = 1 Samples = [215]
# Merged Cluster 251: Size = 1 Samples = [216]
# Merged Cluster 252: Size = 1 Samples = [217]
# Merged Cluster 253: Size = 1 Samples = [218]
# Merged Cluster 254: Size = 1 Samples = [219]
# Merged Cluster 255: Size = 1 Samples = [220]
# Merged Cluster 256: Size = 1 Samples = [221]
# Merged Cluster 257: Size = 1 Samples = [222]
# Merged Cluster 258: Size = 1 Samples = [223]
# Merged Cluster 259: Size = 1 Samples = [224]
# Merged Cluster 260: Size = 1 Samples = [225]
# Merged Cluster 261: Size = 1 Samples = [226]
# Merged Cluster 262: Size = 1 Samples = [227]
# Merged Cluster 263: Size = 1 Samples = [228]
# Merged Cluster 264: Size = 1 Samples = [229]
# Merged Cluster 265: Size = 1 Samples = [230]
# Merged Cluster 266: Size = 1 Samples = [231]
# Merged Cluster 267: Size = 1 Samples = [232]
# Merged Cluster 268: Size = 1 Samples = [233]
# Merged Cluster 269: Size = 1 Samples = [234]
# Merged Cluster 270: Size = 1 Samples = [235]
# Merged Cluster 271: Size = 1 Samples = [236]
# Merged Cluster 272: Size = 1 Samples = [237]
# Merged Cluster 273: Size = 1 Samples = [238]
# Merged Cluster 274: Size = 1 Samples = [239]
# Merged Cluster 275: Size = 1 Samples = [240]
# Merged Cluster 276: Size = 1 Samples = [241]
# Merged Cluster 277: Size = 1 Samples = [242]
# Merged Cluster 278: Size = 1 Samples = [243]
# Merged Cluster 279: Size = 1 Samples = [244]
# Merged Cluster 280: Size = 1 Samples = [245]
# Merged Cluster 281: Size = 1 Samples = [246]
# Merged Cluster 282: Size = 1 Samples = [247]
# Merged Cluster 283: Size = 1 Samples = [248]
# Merged Cluster 284: Size = 1 Samples = [249]
# Merged Cluster 285: Size = 1 Samples = [250]
# Merged Cluster 286: Size = 1 Samples = [251]
# Merged Cluster 287: Size = 1 Samples = [252]
# Merged Cluster 288: Size = 1 Samples = [253]
# Merged Cluster 289: Size = 1 Samples = [254]
# Merged Cluster 290: Size = 1 Samples = [255]
# Merged Cluster 291: Size = 1 Samples = [256]
# Merged Cluster 292: Size = 1 Samples = [257]
# Merged Cluster 293: Size = 1 Samples = [258]
# Merged Cluster 294: Size = 1 Samples = [259]
# Merged Cluster 295: Size = 1 Samples = [260]
# Merged Cluster 296: Size = 1 Samples = [261]
# Merged Cluster 297: Size = 1 Samples = [262]
# Merged Cluster 298: Size = 1 Samples = [263]
# Merged Cluster 299: Size = 1 Samples = [265]
# Merged Cluster 300: Size = 1 Samples = [266]
# Merged Cluster 301: Size = 1 Samples = [267]
# Merged Cluster 302: Size = 1 Samples = [268]
# Merged Cluster 303: Size = 1 Samples = [270]
# Merged Cluster 304: Size = 1 Samples = [271]
# Merged Cluster 305: Size = 1 Samples = [272]
# Merged Cluster 306: Size = 1 Samples = [273]
# Merged Cluster 307: Size = 1 Samples = [274]
# Merged Cluster 308: Size = 1 Samples = [275]
# Merged Cluster 309: Size = 1 Samples = [276]
# Merged Cluster 310: Size = 1 Samples = [277]
# Merged Cluster 311: Size = 1 Samples = [278]
# Merged Cluster 312: Size = 1 Samples = [279]
# Merged Cluster 313: Size = 1 Samples = [280]
# Merged Cluster 314: Size = 1 Samples = [281]
# Merged Cluster 315: Size = 1 Samples = [282]
# Merged Cluster 316: Size = 1 Samples = [283]
# Merged Cluster 317: Size = 1 Samples = [284]
# Merged Cluster 318: Size = 1 Samples = [290]
# Merged Cluster 319: Size = 1 Samples = [291]
# Merged Cluster 320: Size = 1 Samples = [292]
# Merged Cluster 321: Size = 1 Samples = [294]
# Merged Cluster 322: Size = 1 Samples = [295]
# Merged Cluster 323: Size = 1 Samples = [296]
# Merged Cluster 324: Size = 1 Samples = [297]
# Merged Cluster 325: Size = 1 Samples = [298]
# Merged Cluster 326: Size = 1 Samples = [299]
# Merged Cluster 327: Size = 1 Samples = [300]
# Merged Cluster 328: Size = 1 Samples = [301]
# Merged Cluster 329: Size = 1 Samples = [302]
# Merged Cluster 330: Size = 1 Samples = [303]
# Merged Cluster 331: Size = 1 Samples = [304]
# Merged Cluster 332: Size = 1 Samples = [305]
# Merged Cluster 333: Size = 1 Samples = [306]
# Merged Cluster 334: Size = 1 Samples = [307]
# Merged Cluster 335: Size = 1 Samples = [308]
# Merged Cluster 336: Size = 1 Samples = [309]
# Merged Cluster 337: Size = 1 Samples = [310]
# Merged Cluster 338: Size = 1 Samples = [311]
# Merged Cluster 339: Size = 1 Samples = [312]
# Merged Cluster 340: Size = 1 Samples = [313]
# Merged Cluster 341: Size = 1 Samples = [314]
# Merged Cluster 342: Size = 1 Samples = [315]
# Merged Cluster 343: Size = 1 Samples = [317]
# Merged Cluster 344: Size = 1 Samples = [318]
# Merged Cluster 345: Size = 1 Samples = [319]
# Merged Cluster 346: Size = 1 Samples = [320]
# Merged Cluster 347: Size = 1 Samples = [321]
# Merged Cluster 348: Size = 1 Samples = [323]
# Merged Cluster 349: Size = 1 Samples = [324]
# Merged Cluster 350: Size = 1 Samples = [325]
# Merged Cluster 351: Size = 1 Samples = [326]
# Merged Cluster 352: Size = 1 Samples = [327]
# Merged Cluster 353: Size = 1 Samples = [328]
# Merged Cluster 354: Size = 1 Samples = [329]
# Merged Cluster 355: Size = 1 Samples = [330]
# Merged Cluster 356: Size = 1 Samples = [331]
# Merged Cluster 357: Size = 1 Samples = [332]
# Merged Cluster 358: Size = 1 Samples = [333]
# Merged Cluster 359: Size = 1 Samples = [334]
# Merged Cluster 360: Size = 1 Samples = [335]
# Merged Cluster 361: Size = 1 Samples = [336]
# Merged Cluster 362: Size = 1 Samples = [337]
# Merged Cluster 363: Size = 1 Samples = [339]
# Merged Cluster 364: Size = 1 Samples = [340]
# Merged Cluster 365: Size = 1 Samples = [341]
# Merged Cluster 366: Size = 1 Samples = [342]
# Merged Cluster 367: Size = 1 Samples = [343]
# Merged Cluster 368: Size = 1 Samples = [344]
# Merged Cluster 369: Size = 1 Samples = [345]
# Merged Cluster 370: Size = 1 Samples = [346]
# Merged Cluster 371: Size = 1 Samples = [348]
# Merged Cluster 372: Size = 1 Samples = [349]
# Merged Cluster 373: Size = 1 Samples = [350]
# Merged Cluster 374: Size = 1 Samples = [351]
# Merged Cluster 375: Size = 1 Samples = [352]
# Merged Cluster 376: Size = 1 Samples = [353]
# Merged Cluster 377: Size = 1 Samples = [354]
# Merged Cluster 378: Size = 1 Samples = [355]
# Merged Cluster 379: Size = 1 Samples = [356]
# Merged Cluster 380: Size = 1 Samples = [357]
# Merged Cluster 381: Size = 1 Samples = [358]
# Merged Cluster 382: Size = 1 Samples = [359]
# Merged Cluster 383: Size = 1 Samples = [360]
# Merged Cluster 384: Size = 1 Samples = [361]
# Merged Cluster 385: Size = 1 Samples = [362]
# Merged Cluster 386: Size = 1 Samples = [363]
# Merged Cluster 387: Size = 1 Samples = [364]
# Merged Cluster 388: Size = 1 Samples = [365]
# Merged Cluster 389: Size = 1 Samples = [366]
# Merged Cluster 390: Size = 1 Samples = [367]
# Merged Cluster 391: Size = 1 Samples = [368]
# Merged Cluster 392: Size = 1 Samples = [369]
# Merged Cluster 393: Size = 1 Samples = [370]
# Merged Cluster 394: Size = 1 Samples = [371]
# Merged Cluster 395: Size = 1 Samples = [372]
# Merged Cluster 396: Size = 1 Samples = [373]
# Merged Cluster 397: Size = 1 Samples = [374]
# Merged Cluster 398: Size = 1 Samples = [375]
# Merged Cluster 399: Size = 1 Samples = [377]
# Merged Cluster 400: Size = 1 Samples = [378]
# Merged Cluster 401: Size = 1 Samples = [379]
# Merged Cluster 402: Size = 1 Samples = [380]
# Merged Cluster 403: Size = 1 Samples = [381]
# Merged Cluster 404: Size = 1 Samples = [382]
# Merged Cluster 405: Size = 1 Samples = [383]
# Merged Cluster 406: Size = 1 Samples = [384]
# Merged Cluster 407: Size = 1 Samples = [385]
# Merged Cluster 408: Size = 1 Samples = [386]
# Merged Cluster 409: Size = 1 Samples = [387]
# Merged Cluster 410: Size = 1 Samples = [388]
# Merged Cluster 411: Size = 1 Samples = [389]
# Merged Cluster 412: Size = 1 Samples = [390]
# Merged Cluster 413: Size = 1 Samples = [391]
# Merged Cluster 414: Size = 1 Samples = [392]
# Merged Cluster 415: Size = 1 Samples = [393]
# Merged Cluster 416: Size = 1 Samples = [394]
# Merged Cluster 417: Size = 1 Samples = [395]
# Merged Cluster 418: Size = 1 Samples = [396]
# Merged Cluster 419: Size = 1 Samples = [397]
# Merged Cluster 420: Size = 1 Samples = [398]
# Merged Cluster 421: Size = 1 Samples = [399]
# Merged Cluster 422: Size = 1 Samples = [400]
# Merged Cluster 423: Size = 1 Samples = [401]
# Merged Cluster 424: Size = 1 Samples = [402]
# Merged Cluster 425: Size = 1 Samples = [403]
# Merged Cluster 426: Size = 1 Samples = [404]
# Merged Cluster 427: Size = 1 Samples = [405]
# Merged Cluster 428: Size = 1 Samples = [406]
# Merged Cluster 429: Size = 1 Samples = [407]
# Merged Cluster 430: Size = 1 Samples = [408]
# Merged Cluster 431: Size = 1 Samples = [410]
# Merged Cluster 432: Size = 1 Samples = [411]
# Merged Cluster 433: Size = 1 Samples = [412]
# Merged Cluster 434: Size = 1 Samples = [414]
# Merged Cluster 435: Size = 1 Samples = [415]
# Merged Cluster 436: Size = 1 Samples = [416]
# Merged Cluster 437: Size = 1 Samples = [417]
# Merged Cluster 438: Size = 1 Samples = [418]
# Merged Cluster 439: Size = 1 Samples = [419]
# Merged Cluster 440: Size = 1 Samples = [420]
# Merged Cluster 441: Size = 1 Samples = [422]
# Merged Cluster 442: Size = 1 Samples = [423]
# Merged Cluster 443: Size = 1 Samples = [424]
# Merged Cluster 444: Size = 1 Samples = [425]
# Merged Cluster 445: Size = 1 Samples = [427]
# Merged Cluster 446: Size = 1 Samples = [428]
# Merged Cluster 447: Size = 1 Samples = [429]
# Merged Cluster 448: Size = 1 Samples = [430]
# Merged Cluster 449: Size = 1 Samples = [431]
# Merged Cluster 450: Size = 1 Samples = [432]
# Merged Cluster 451: Size = 1 Samples = [433]
# Merged Cluster 452: Size = 1 Samples = [434]
# Merged Cluster 453: Size = 1 Samples = [435]
# Merged Cluster 454: Size = 1 Samples = [436]
# Merged Cluster 455: Size = 1 Samples = [437]
# Merged Cluster 456: Size = 1 Samples = [438]
# Merged Cluster 457: Size = 1 Samples = [439]
# Merged Cluster 458: Size = 1 Samples = [440]
# Merged Cluster 459: Size = 1 Samples = [441]
# Merged Cluster 460: Size = 1 Samples = [444]
# Merged Cluster 461: Size = 1 Samples = [445]
# Merged Cluster 462: Size = 1 Samples = [446]
# Merged Cluster 463: Size = 1 Samples = [447]
# Merged Cluster 464: Size = 1 Samples = [448]
# Merged Cluster 465: Size = 1 Samples = [449]
# Merged Cluster 466: Size = 1 Samples = [452]
# Merged Cluster 467: Size = 1 Samples = [453]
# Merged Cluster 468: Size = 1 Samples = [455]
# Merged Cluster 469: Size = 1 Samples = [456]
# Merged Cluster 470: Size = 1 Samples = [457]
# Merged Cluster 471: Size = 1 Samples = [458]
# Merged Cluster 472: Size = 1 Samples = [459]
# Merged Cluster 473: Size = 1 Samples = [463]
# Merged Cluster 474: Size = 1 Samples = [467]
# Merged Cluster 475: Size = 1 Samples = [468]
# Merged Cluster 476: Size = 1 Samples = [469]
# Merged Cluster 477: Size = 1 Samples = [470]
# Merged Cluster 478: Size = 1 Samples = [471]
# Merged Cluster 479: Size = 1 Samples = [472]
# Merged Cluster 480: Size = 1 Samples = [473]
# Merged Cluster 481: Size = 1 Samples = [474]
# Merged Cluster 482: Size = 1 Samples = [475]
# Merged Cluster 483: Size = 1 Samples = [476]
# Merged Cluster 484: Size = 1 Samples = [478]
# Merged Cluster 485: Size = 1 Samples = [479]
# Merged Cluster 486: Size = 1 Samples = [480]
# Merged Cluster 487: Size = 1 Samples = [481]
# Merged Cluster 488: Size = 1 Samples = [482]
# Merged Cluster 489: Size = 1 Samples = [483]
# Merged Cluster 490: Size = 1 Samples = [484]
# Merged Cluster 491: Size = 1 Samples = [485]
# Merged Cluster 492: Size = 1 Samples = [486]
# Merged Cluster 493: Size = 1 Samples = [487]
# Merged Cluster 494: Size = 1 Samples = [488]
# Merged Cluster 495: Size = 1 Samples = [489]
# Merged Cluster 496: Size = 1 Samples = [491]
# Merged Cluster 497: Size = 1 Samples = [492]
# Merged Cluster 498: Size = 1 Samples = [493]
# Merged Cluster 499: Size = 1 Samples = [494]
# Merged Cluster 500: Size = 1 Samples = [495]
# Merged Cluster 501: Size = 1 Samples = [496]
# Merged Cluster 502: Size = 1 Samples = [500]
# Merged Cluster 503: Size = 1 Samples = [501]
# Merged Cluster 504: Size = 1 Samples = [502]
# Merged Cluster 505: Size = 1 Samples = [504]
# Merged Cluster 506: Size = 1 Samples = [506]
# Merged Cluster 507: Size = 1 Samples = [507]
# Merged Cluster 508: Size = 1 Samples = [508]
# Merged Cluster 509: Size = 1 Samples = [509]
# Merged Cluster 510: Size = 1 Samples = [510]
# Merged Cluster 511: Size = 1 Samples = [511]
# Merged Cluster 512: Size = 1 Samples = [512]
# Merged Cluster 513: Size = 1 Samples = [513]
# Merged Cluster 514: Size = 1 Samples = [514]
# Merged Cluster 515: Size = 1 Samples = [515]
# Merged Cluster 516: Size = 1 Samples = [516]
# Merged Cluster 517: Size = 1 Samples = [517]
# Merged Cluster 518: Size = 1 Samples = [518]
# Merged Cluster 519: Size = 1 Samples = [519]
# Merged Cluster 520: Size = 1 Samples = [520]
# Merged Cluster 521: Size = 1 Samples = [521]
# Merged Cluster 522: Size = 1 Samples = [522]
# Merged Cluster 523: Size = 1 Samples = [523]
# Merged Cluster 524: Size = 1 Samples = [524]
# Merged Cluster 525: Size = 1 Samples = [526]
# Merged Cluster 526: Size = 1 Samples = [528]
# Merged Cluster 527: Size = 1 Samples = [529]
# Merged Cluster 528: Size = 1 Samples = [530]
# Merged Cluster 529: Size = 1 Samples = [531]
# Merged Cluster 530: Size = 1 Samples = [532]
# Merged Cluster 531: Size = 1 Samples = [534]
# Merged Cluster 532: Size = 1 Samples = [535]
# Merged Cluster 533: Size = 1 Samples = [537]
# Merged Cluster 534: Size = 1 Samples = [539]
# Merged Cluster 535: Size = 1 Samples = [540]
# Merged Cluster 536: Size = 1 Samples = [541]
# Merged Cluster 537: Size = 1 Samples = [542]
# Merged Cluster 538: Size = 1 Samples = [543]
# Merged Cluster 539: Size = 1 Samples = [544]
# Merged Cluster 540: Size = 1 Samples = [545]
# Merged Cluster 541: Size = 1 Samples = [546]
# Merged Cluster 542: Size = 1 Samples = [547]
# Merged Cluster 543: Size = 1 Samples = [549]
# Merged Cluster 544: Size = 1 Samples = [553]
# Merged Cluster 545: Size = 1 Samples = [554]
# Merged Cluster 546: Size = 1 Samples = [555]
# Merged Cluster 547: Size = 1 Samples = [557]
# Merged Cluster 548: Size = 1 Samples = [558]
# Merged Cluster 549: Size = 1 Samples = [559]
# Merged Cluster 550: Size = 1 Samples = [560]
# Merged Cluster 551: Size = 1 Samples = [561]
# Merged Cluster 552: Size = 1 Samples = [562]
# Merged Cluster 553: Size = 1 Samples = [564]
# Merged Cluster 554: Size = 1 Samples = [565]
# Merged Cluster 555: Size = 1 Samples = [566]
# Merged Cluster 556: Size = 1 Samples = [567]
# Merged Cluster 557: Size = 1 Samples = [569]
# Merged Cluster 558: Size = 1 Samples = [570]
# Merged Cluster 559: Size = 1 Samples = [571]
# Merged Cluster 560: Size = 1 Samples = [572]
# Merged Cluster 561: Size = 1 Samples = [573]
# Merged Cluster 562: Size = 1 Samples = [574]
# Merged Cluster 563: Size = 1 Samples = [575]
# Merged Cluster 564: Size = 1 Samples = [577]
# Merged Cluster 565: Size = 1 Samples = [578]
# Merged Cluster 566: Size = 1 Samples = [579]
# Merged Cluster 567: Size = 1 Samples = [580]
# Merged Cluster 568: Size = 1 Samples = [581]
# Merged Cluster 569: Size = 1 Samples = [582]
# Merged Cluster 570: Size = 1 Samples = [583]
# Merged Cluster 571: Size = 1 Samples = [584]
# Merged Cluster 572: Size = 1 Samples = [585]
# Merged Cluster 573: Size = 1 Samples = [586]
# Merged Cluster 574: Size = 1 Samples = [587]
# Merged Cluster 575: Size = 1 Samples = [588]
# Merged Cluster 576: Size = 1 Samples = [589]
# Merged Cluster 577: Size = 1 Samples = [590]
# Merged Cluster 578: Size = 1 Samples = [591]
# Merged Cluster 579: Size = 1 Samples = [592]
# Merged Cluster 580: Size = 1 Samples = [593]
# Merged Cluster 581: Size = 1 Samples = [594]
# Merged Cluster 582: Size = 1 Samples = [595]
# Merged Cluster 583: Size = 1 Samples = [596]
# Merged Cluster 584: Size = 1 Samples = [598]
# Merged Cluster 585: Size = 1 Samples = [599]
# Merged Cluster 586: Size = 1 Samples = [601]
# Merged Cluster 587: Size = 1 Samples = [602]
# Merged Cluster 588: Size = 1 Samples = [604]
# Merged Cluster 589: Size = 1 Samples = [605]
# Merged Cluster 590: Size = 1 Samples = [606]
# Merged Cluster 591: Size = 1 Samples = [607]
# Merged Cluster 592: Size = 1 Samples = [608]
# Merged Cluster 593: Size = 1 Samples = [609]
# Merged Cluster 594: Size = 1 Samples = [610]
# Merged Cluster 595: Size = 1 Samples = [611]
# Merged Cluster 596: Size = 1 Samples = [612]
# Merged Cluster 597: Size = 1 Samples = [613]
# Merged Cluster 598: Size = 1 Samples = [614]
# Merged Cluster 599: Size = 1 Samples = [615]
# Merged Cluster 600: Size = 1 Samples = [616]
# Merged Cluster 601: Size = 1 Samples = [617]
# Merged Cluster 602: Size = 1 Samples = [618]
# Merged Cluster 603: Size = 1 Samples = [619]
# Merged Cluster 604: Size = 1 Samples = [620]
# Merged Cluster 605: Size = 1 Samples = [621]
# Merged Cluster 606: Size = 1 Samples = [622]
# Merged Cluster 607: Size = 1 Samples = [623]

# %% [markdown]
# # Remove Outliers
